# %% [markdown]
# Notebook for demonstrating the HHL algorithm.
#
# Cambridge Consultants 2024\
# Walden Killick

# %%
from qiskit import QuantumCircuit

from qce24_qre_challenge.circuit.hhl import HHL

# %%
target_unitary = QuantumCircuit(1)
target_unitary.rz(0.1, 0)

hhl = HHL(3, target_unitary, [0, 1])

hhl_circuit = hhl.create_circuit()

hhl_circuit.draw('mpl')
