# %% [markdown]
# Notebook for fitting the qubit counts from the resource estimates.
#
# Cambridge Consultants 2024\
# Walden Killick

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# Data from the resource estimator
x_matrix_sizes = [4, 8, 16, 32, 64, 128, 256]
y_logical_qubits = [20, 23, 25, 28, 30, 33, 35]
y_physical_qubits = [333000, 334350, 284450, 304180, 273660, 556950, 591710]

# Data without the anomalous results
x_remove_anomalies = [4, 8, 128, 256]
y_physical_remove_anomalies = [333000, 334350, 556950, 591710]

# %%
a_logical, b_logical = np.polyfit(np.log(x_matrix_sizes), y_logical_qubits, 1)
print(f"Logical qubits fit: {a_logical:.3f}*log(x)+{b_logical:.3f}")

a_physical, b_physical = np.polyfit(np.log(x_remove_anomalies), y_physical_remove_anomalies, 1)
print(f"Physical qubits fit: {a_physical:.3f}*log(x)+{b_physical:.3f}")
# Out:
# Logical qubits fit: 3.607*log(x)+15.214
# Physical qubits fit: 67769.490*log(x)+219131.346

# %%
x = np.linspace(4, 256, 100)
y_logical_qubits_fitted = [a_logical*np.log(t) + b_logical for t in x]
y_physical_qubits_fitted = [a_physical*np.log(t) + b_physical for t in x]

# %%
plt.plot(x_matrix_sizes, y_logical_qubits, 'x', label='Logical qubits')
plt.plot(x, y_logical_qubits_fitted, label='Logarithmic fit')
plt.xlabel('Matrix dimension')
plt.ylabel('Qubits')
plt.title('Logical qubit requirements')
plt.legend()
plt.show()

# %%
plt.plot(x_matrix_sizes, y_physical_qubits, 'x', label='Physical qubits')
plt.plot(x, y_physical_qubits_fitted, label='Logarithmic fit')
plt.xlabel('Matrix dimension')
plt.ylabel('Qubits')
plt.title('Physical qubit requirements')
plt.legend()
plt.show()
