# %% [markdown]
# Notebook for generating resource estimates for QSVT circuits.
#
# Cambridge Consultants 2024\
# Walden Killick

# %%
from azure.quantum import Workspace

workspace = Workspace (
   resource_id = "/subscriptions/a0f970ef-72e9-4075-8009-32c19007a132/resourceGroups/AzureQuantum/providers/Microsoft.Quantum/Workspaces/QCE24-QRE-Challenge",
   location = "uksouth"
)

# %%
from azure.quantum.qiskit import AzureQuantumProvider
from qiskit import QuantumCircuit

# %%
provider = AzureQuantumProvider(workspace)
backend = provider.get_backend('microsoft.estimator')

# %%
from pathlib import Path

path = Path.cwd().parents[1].joinpath('qasm_circuits/qsvt_circuits')
circuit_dict = {}
for file_path in list(path.iterdir()):
    with open(file_path, "r") as file:
        circuit_dict[file_path.name] = file.read()

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_4'])

job = backend.run(qiskit_circuit)
result = job.result()
result
# Out:
# ........
# {'status': 'success',
#  'jobParams': {'qecScheme': {'name': 'surface_code',
#    'errorCorrectionThreshold': 0.01,
#    'crossingPrefactor': 0.03,
#    'logicalCycleTime': '(4 * twoQubitGateTime + 2 * oneQubitMeasurementTime) * codeDistance',
#    'physicalQubitsPerLogicalQubit': '2 * codeDistance * codeDistance',
#    'maxCodeDistance': 50},
#   'errorBudget': 0.001,
#   'qubitParams': {'instructionSet': 'GateBased',
#    'name': 'qubit_gate_ns_e3',
#    'oneQubitMeasurementTime': '100 ns',
#    'oneQubitGateTime': '50 ns',
#    'twoQubitGateTime': '50 ns',
#    'tGateTime': '50 ns',
#    'oneQubitMeasurementErrorRate': 0.001,
#    'oneQubitGateErrorRate': 0.001,
#    'twoQubitGateErrorRate': 0.001,
#    'tGateErrorRate': 0.001,
#    'idleErrorRate': 0.001}},
#  'physicalCounts': {'physicalQubits': 333000,
#   'runtime': 105738000,
#   'rqops': 3333334,
#   'breakdown': {'algorithmicLogicalQubits': 20,
#    'algorithmicLogicalDepth': 17623,
#    'logicalDepth': 17623,
# ...

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_8'])

job = backend.run(qiskit_circuit)
result = job.result()
result
# Out:
# ......
# {'status': 'success',
#  'jobParams': {'qecScheme': {'name': 'surface_code',
#    'errorCorrectionThreshold': 0.01,
#    'crossingPrefactor': 0.03,
#    'logicalCycleTime': '(4 * twoQubitGateTime + 2 * oneQubitMeasurementTime) * codeDistance',
#    'physicalQubitsPerLogicalQubit': '2 * codeDistance * codeDistance',
#    'maxCodeDistance': 50},
#   'errorBudget': 0.001,
#   'qubitParams': {'instructionSet': 'GateBased',
#    'name': 'qubit_gate_ns_e3',
#    'oneQubitMeasurementTime': '100 ns',
#    'oneQubitGateTime': '50 ns',
#    'twoQubitGateTime': '50 ns',
#    'tGateTime': '50 ns',
#    'oneQubitMeasurementErrorRate': 0.001,
#    'oneQubitGateErrorRate': 0.001,
#    'twoQubitGateErrorRate': 0.001,
#    'tGateErrorRate': 0.001,
#    'idleErrorRate': 0.001}},
#  'physicalCounts': {'physicalQubits': 334350,
#   'runtime': 208872000,
#   'rqops': 3833334,
#   'breakdown': {'algorithmicLogicalQubits': 23,
#    'algorithmicLogicalDepth': 34812,
#    'logicalDepth': 34812,
# ...

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_16'])

job = backend.run(qiskit_circuit)
result = job.result()
result
# Out:
# .......
# {'status': 'success',
#  'jobParams': {'qecScheme': {'name': 'surface_code',
#    'errorCorrectionThreshold': 0.01,
#    'crossingPrefactor': 0.03,
#    'logicalCycleTime': '(4 * twoQubitGateTime + 2 * oneQubitMeasurementTime) * codeDistance',
#    'physicalQubitsPerLogicalQubit': '2 * codeDistance * codeDistance',
#    'maxCodeDistance': 50},
#   'errorBudget': 0.001,
#   'qubitParams': {'instructionSet': 'GateBased',
#    'name': 'qubit_gate_ns_e3',
#    'oneQubitMeasurementTime': '100 ns',
#    'oneQubitGateTime': '50 ns',
#    'twoQubitGateTime': '50 ns',
#    'tGateTime': '50 ns',
#    'oneQubitMeasurementErrorRate': 0.001,
#    'oneQubitGateErrorRate': 0.001,
#    'twoQubitGateErrorRate': 0.001,
#    'tGateErrorRate': 0.001,
#    'idleErrorRate': 0.001}},
#  'physicalCounts': {'physicalQubits': 284450,
#   'runtime': 589641600,
#   'rqops': 3676471,
#   'breakdown': {'algorithmicLogicalQubits': 25,
#    'algorithmicLogicalDepth': 86712,
#    'logicalDepth': 86712,
# ...

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_32'])

job = backend.run(qiskit_circuit)
result = job.result()
result
# Out:
# ...........
# {'status': 'success',
#  'jobParams': {'qecScheme': {'name': 'surface_code',
#    'errorCorrectionThreshold': 0.01,
#    'crossingPrefactor': 0.03,
#    'logicalCycleTime': '(4 * twoQubitGateTime + 2 * oneQubitMeasurementTime) * codeDistance',
#    'physicalQubitsPerLogicalQubit': '2 * codeDistance * codeDistance',
#    'maxCodeDistance': 50},
#   'errorBudget': 0.001,
#   'qubitParams': {'instructionSet': 'GateBased',
#    'name': 'qubit_gate_ns_e3',
#    'oneQubitMeasurementTime': '100 ns',
#    'oneQubitGateTime': '50 ns',
#    'twoQubitGateTime': '50 ns',
#    'tGateTime': '50 ns',
#    'oneQubitMeasurementErrorRate': 0.001,
#    'oneQubitGateErrorRate': 0.001,
#    'twoQubitGateErrorRate': 0.001,
#    'tGateErrorRate': 0.001,
#    'idleErrorRate': 0.001}},
#  'physicalCounts': {'physicalQubits': 304184,
#   'runtime': 1372151600,
#   'rqops': 4117648,
#   'breakdown': {'algorithmicLogicalQubits': 28,
#    'algorithmicLogicalDepth': 201787,
# ...

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_64'])

job = backend.run(qiskit_circuit)
result = job.result()
result
# Out:
# ............
# {'status': 'success',
#  'jobParams': {'qecScheme': {'name': 'surface_code',
#    'errorCorrectionThreshold': 0.01,
#    'crossingPrefactor': 0.03,
#    'logicalCycleTime': '(4 * twoQubitGateTime + 2 * oneQubitMeasurementTime) * codeDistance',
#    'physicalQubitsPerLogicalQubit': '2 * codeDistance * codeDistance',
#    'maxCodeDistance': 50},
#   'errorBudget': 0.001,
#   'qubitParams': {'instructionSet': 'GateBased',
#    'name': 'qubit_gate_ns_e3',
#    'oneQubitMeasurementTime': '100 ns',
#    'oneQubitGateTime': '50 ns',
#    'twoQubitGateTime': '50 ns',
#    'tGateTime': '50 ns',
#    'oneQubitMeasurementErrorRate': 0.001,
#    'oneQubitGateErrorRate': 0.001,
#    'twoQubitGateErrorRate': 0.001,
#    'tGateErrorRate': 0.001,
#    'idleErrorRate': 0.001}},
#  'physicalCounts': {'physicalQubits': 273660,
#   'runtime': 4210324000,
#   'rqops': 3947369,
#   'breakdown': {'algorithmicLogicalQubits': 30,
#    'algorithmicLogicalDepth': 553990,
# ...

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_128'])

job = backend.run(qiskit_circuit)
result = job.result()
result
# Out:
# ...............
# {'status': 'success',
#  'jobParams': {'qecScheme': {'name': 'surface_code',
#    'errorCorrectionThreshold': 0.01,
#    'crossingPrefactor': 0.03,
#    'logicalCycleTime': '(4 * twoQubitGateTime + 2 * oneQubitMeasurementTime) * codeDistance',
#    'physicalQubitsPerLogicalQubit': '2 * codeDistance * codeDistance',
#    'maxCodeDistance': 50},
#   'errorBudget': 0.001,
#   'qubitParams': {'instructionSet': 'GateBased',
#    'name': 'qubit_gate_ns_e3',
#    'oneQubitMeasurementTime': '100 ns',
#    'oneQubitGateTime': '50 ns',
#    'twoQubitGateTime': '50 ns',
#    'tGateTime': '50 ns',
#    'oneQubitMeasurementErrorRate': 0.001,
#    'oneQubitGateErrorRate': 0.001,
#    'twoQubitGateErrorRate': 0.001,
#    'tGateErrorRate': 0.001,
#    'idleErrorRate': 0.001}},
#  'physicalCounts': {'physicalQubits': 556946,
#   'runtime': 8321620000,
#   'rqops': 4342106,
#   'breakdown': {'algorithmicLogicalQubits': 33,
#    'algorithmicLogicalDepth': 1094950,
# ...

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_256'])

job = backend.run(qiskit_circuit)
result = job.result()
result
# Out:
# ............................
# {'status': 'success',
#  'jobParams': {'qecScheme': {'name': 'surface_code',
#    'errorCorrectionThreshold': 0.01,
#    'crossingPrefactor': 0.03,
#    'logicalCycleTime': '(4 * twoQubitGateTime + 2 * oneQubitMeasurementTime) * codeDistance',
#    'physicalQubitsPerLogicalQubit': '2 * codeDistance * codeDistance',
#    'maxCodeDistance': 50},
#   'errorBudget': 0.001,
#   'qubitParams': {'instructionSet': 'GateBased',
#    'name': 'qubit_gate_ns_e3',
#    'oneQubitMeasurementTime': '100 ns',
#    'oneQubitGateTime': '50 ns',
#    'twoQubitGateTime': '50 ns',
#    'tGateTime': '50 ns',
#    'oneQubitMeasurementErrorRate': 0.001,
#    'oneQubitGateErrorRate': 0.001,
#    'twoQubitGateErrorRate': 0.001,
#    'tGateErrorRate': 0.001,
#    'idleErrorRate': 0.001}},
#  'physicalCounts': {'physicalQubits': 591710,
#   'runtime': 15374108400,
#   'rqops': 4605264,
#   'breakdown': {'algorithmicLogicalQubits': 35,
#    'algorithmicLogicalDepth': 2022909,
# ...

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_512'])

job = backend.run(qiskit_circuit)
result = job.result()
result
# Out:
# ...................................................
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 4
#       1 qiskit_circuit = QuantumCircuit.from_qasm_str(qsvt_512)
#       3 job = backend.run(qiskit_circuit)
# ----> 4 result = job.result()
#       5 result
#
# File /usr/local/lib/python3.11/site-packages/azure/quantum/qiskit/job.py:100, in AzureQuantumJob.result(self, timeout, sampler_seed)
#      89 result_dict = {
#      90     "results" : results if isinstance(results, list) else [results],
#      91     "job_id" : self._azure_job.details.id,
#    (...)
#      96     "error_data" : None if self._azure_job.details.error_data is None else self._azure_job.details.error_data.as_dict()
#      97 }
#      99 if self._azure_job.details.output_data_format == RESOURCE_ESTIMATOR_OUTPUT_DATA_FORMAT:
# --> 100     return make_estimator_result(result_dict)
# ...

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_1024'])

job = backend.run(qiskit_circuit)
result = job.result()
result

# %%
qiskit_circuit = QuantumCircuit.from_qasm_str(circuit_dict['qsvt_2048'])

job = backend.run(qiskit_circuit)
result = job.result()
result
